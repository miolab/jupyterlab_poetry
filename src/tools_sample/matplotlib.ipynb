# %%
"""Matplotlib samples
"""
import numpy as np
import matplotlib.pyplot as plt

# Draw a line chart with elements on Y-axis and indices on X-axis.
plt.plot(
    [1, 2, 3, 4, 5]
)
plt.show()

# %%
plt.plot(
    # X-axis to Y-axis
    [1, 2, 3, 4, 5],
    [1, 4, 9, 16, 25]
)
plt.show()
