# %% [markdown]
# # Simple regression analysis sample
#
# ## dataset
#
# - California housing dataset
#   https://scikit-learn.org/stable/modules/generated/sklearn.datasets.fetch_california_housing.html
#
# # ref
# - sklearn.model_selection.train_test_split
#   https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.train_test_split.html#sklearn-model-selection-train-test-split
# - sklearn.linear_model.LinearRegression
#   https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score


california = fetch_california_housing()

# %%
# Comfirmation load dataset
print(f'Column names: {len(california.feature_names)}\n{california.feature_names}\n')
print(f'Explanatory variable X: {len(california.data)}\n{california.data[:5]}\n')
print(f'Objective variable Y: {len(california.target)}\n{california.target[:5]}\n')
print(california.DESCR)
# Out:
# Column names: 8
# ['MedInc', 'HouseAge', 'AveRooms', 'AveBedrms', 'Population', 'AveOccup', 'Latitude', 'Longitude']
#
# Explanatory variable X: 20640
# [[ 8.32520000e+00  4.10000000e+01  6.98412698e+00  1.02380952e+00
#    3.22000000e+02  2.55555556e+00  3.78800000e+01 -1.22230000e+02]
#  [ 8.30140000e+00  2.10000000e+01  6.23813708e+00  9.71880492e-01
#    2.40100000e+03  2.10984183e+00  3.78600000e+01 -1.22220000e+02]
#  [ 7.25740000e+00  5.20000000e+01  8.28813559e+00  1.07344633e+00
#    4.96000000e+02  2.80225989e+00  3.78500000e+01 -1.22240000e+02]
#  [ 5.64310000e+00  5.20000000e+01  5.81735160e+00  1.07305936e+00
#    5.58000000e+02  2.54794521e+00  3.78500000e+01 -1.22250000e+02]
#  [ 3.84620000e+00  5.20000000e+01  6.28185328e+00  1.08108108e+00
#    5.65000000e+02  2.18146718e+00  3.78500000e+01 -1.22250000e+02]]
#
# Objective variable Y: 20640
# [4.526 3.585 3.521 3.413 3.422]
#
# .. _california_housing_dataset:
#
# California Housing dataset
# ...

# %%
df = pd.DataFrame(
    california.data,
    columns=california.feature_names
)

display(df.head())
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25

# %%
# Add objective variable to dataframe.
df['Price'] = california.target

df.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  Price
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %%
# Overview understanding of data.
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude         Price
# count  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704      2.068558
# std       10.386050      2.135952      2.003532      1.153956
# ...

# %%
plt.figure(figsize=(18, 8))

for i, column in enumerate(df.columns):
    plt.subplot(
        2,
        5,
        i + 1
    )
    plt.title(column)
    plt.hist(df[column])

plt.tight_layout()
plt.show()

# %%
# Correlation check.
df_corr = df.corr()

display(df_corr)
# Out:
#               MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# MedInc      1.000000 -0.119034  0.326895  -0.062040    0.004834  0.018766
# HouseAge   -0.119034  1.000000 -0.153277  -0.077747   -0.296244  0.013191
# AveRooms    0.326895 -0.153277  1.000000   0.847621   -0.072213 -0.004852
# AveBedrms  -0.062040 -0.077747  0.847621   1.000000   -0.066197 -0.006181
# Population  0.004834 -0.296244 -0.072213  -0.066197    1.000000  0.069863
# AveOccup    0.018766  0.013191 -0.004852  -0.006181    0.069863  1.000000
# Latitude   -0.079809  0.011173  0.106389   0.069721   -0.108785  0.002366
# Longitude  -0.015176 -0.108197 -0.027540   0.013344    0.099773  0.002476
# Price       0.688075  0.105623  0.151948  -0.046701   -0.024650 -0.023737
#
#             Latitude  Longitude     Price
# MedInc     -0.079809  -0.015176  0.688075
# HouseAge    0.011173  -0.108197  0.105623
# AveRooms    0.106389  -0.027540  0.151948
# AveBedrms   0.069721   0.013344 -0.046701
# ...

# %%
plt.figure(figsize=(18, 8))

sns.heatmap(df_corr, annot=True)
plt.title('Corr Heatmap')
plt.show()

# %% [markdown]
# In considering the results, the __Explanatory variable__ that appears to be particularly correlated with the __Objective variable Price__ is __MedInc__.

# %%
# Split the data into Explanatory and Objective variables.
X = df[['MedInc']]
y = df[['Price']]

display(X.head())
display(y.head())
# Out:
#    MedInc
# 0  8.3252
# 1  8.3014
# 2  7.2574
# 3  5.6431
# 4  3.8462
#    Price
# 0  4.526
# 1  3.585
# 2  3.521
# 3  3.413
# 4  3.422

# %%
# Split dataset into training and test data.
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=0
)

print(f'X_train length: {len(X_train)}')
display(X_train.head())
print(f'\nX_test length: {len(X_test)}')
display(X_test.head())
# Out:
# X_train length: 14448
#       MedInc
# 1989  1.9750
# 256   2.2604
# 7887  6.2990
# 4581  1.7199
# 1993  2.2206
# X_test length: 6192
#        MedInc
# 14740  4.1518
# 10101  5.7796
# 20566  4.3487
# 2670   2.4511
# 15709  5.0049

# %%
# Constructe Simple regression model.
simple_regression = LinearRegression().fit(
    X_train,
    y_train
)

# %%
# Show predicted values.
y_train_predict = simple_regression.predict(X_train)
y_test_predict = simple_regression.predict(X_test)

print(f'y_train_predict: {len(y_train_predict)}\n{y_train_predict}\n')
print(f'y_test_predict: {len(y_test_predict)}\n{y_test_predict}')
# Out:
# y_train_predict: 14448
# [[1.26823324]
#  [1.38893295]
#  [3.09691423]
#  ...
#  [1.78533043]
#  [2.81461901]
#  [1.02006719]]
#
# y_test_predict: 6192
# [[2.18883287]
#  [2.8772526 ]
#  [2.27210467]
#  ...
#  [3.76342701]
#  [1.30663385]
#  [2.41056678]]

# %%
def plot_meta_informations(x_label: str, y_label: str, title: str) -> None:
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(title)
    plt.legend()
    plt.show()

# %%
# Plot predictions for evaluate the model.
plt.scatter(
    X_train,
    y_train_predict,
    label='train'
)
plt.scatter(
    X_test,
    y_test_predict,
    label='test'
)

plot_meta_informations('X', 'y', 'Simple regression model')

print(f'slope: a = {simple_regression.coef_[0][0]}')
print(f'intercept: b = {simple_regression.intercept_[0]}')
# Out:
# slope: a = 0.42291419843159217
# intercept: b = 0.4329776980148201

# %%
# Plot actual and predicted values.
plt.scatter(
    X_train,
    y_train,
    label='train',
    s=8
)
plt.scatter(
    X_test,
    y_test,
    label='test',
    s=8
)
plt.plot(
    X_test,
    y_test_predict,
    color='red'
)

plot_meta_informations('X', 'y', 'Simple regression model')

# %%
# Visualize difference between actual and predicted values using Residual plot.
plt.scatter(
    y_train_predict,
    y_train_predict - y_train,
    label='train'
)
plt.scatter(
    y_test_predict,
    y_test_predict - y_test,
    label='test'
)
plt.plot(
    [0, 10],
    [0, 0],
    color='red'
)

plot_meta_informations('Predict', '(Predict - True)', 'Residual plot')

# %% [markdown]
# Now, we will evaluate the model using the following accuracy metrics.
#
# ## Mean absolute error (MAE)
#
# Average of the sum of the absolute values of each error value.
#
# $$
#   MAE = \frac{\sum_{i=1}^{n}|y_i-\hat{y}_i|}{n}
# $$
#
# - ref
#   - https://scikit-learn.org/stable/modules/model_evaluation.html#mean-absolute-error
#   - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_absolute_error.html
#
# ## Mean squared error (MSE)
#
# Average of the sum of the squared of each error value.
#
# $$
#   MAE = \frac{\sum_{i=1}^{n}(y_i-\hat{y}_i)}{n}^2
# $$
#
# - ref
#   - https://scikit-learn.org/stable/modules/model_evaluation.html#mean-squared-error
#   - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html#sklearn.metrics.mean_squared_error
#
# ## Root mean squared error (RMSE)
#
# Square root of MSE.
#
# $$
#     RMSE = \sqrt{\frac{\sum_{i=1}^{n}(y_i-\hat{y}_i)}{n}^2}
# $$
#
# - ref
#   - https://en.wikipedia.org/wiki/Root-mean-square_deviation
#
# ## R² score, the coefficient of determination
#
# Value of MSE rescaled.
#
# $$
#     R^2 = 1-\frac{\sum_{i=1}^{n}(y_i-f_i)^2}{\sum_{i=1}^{n}(y_i-\overline{y})^2}
# $$
#
# - ref
#   - https://scikit-learn.org/stable/modules/model_evaluation.html#r2-score-the-coefficient-of-determination
#   - https://scikit-learn.org/stable/modules/generated/sklearn.metrics.r2_score.html#sklearn.metrics.r2_score

# %%
def _metrics_result_text(metrics: str, result: float) -> str:
    return f'{metrics} = {round(result, 4)}'


def accuracy_metrics_evaluation(y, y_pred, headline: str) -> None:
    mae: float = mean_absolute_error(y, y_pred)
    mse: float = mean_squared_error(y, y_pred)
    rmse: float = np.sqrt(mse)
    r2score: float = r2_score(y, y_pred)

    print(
        f'{headline}:\n' \
        f"{_metrics_result_text('MAE', mae)}\n" \
        f"{_metrics_result_text('MSE', mse)}\n" \
        f"{_metrics_result_text('RMSE', rmse)}\n" \
        f"{_metrics_result_text('R2', r2score)}"
    )

# %%
# Confirm accuracy assessment.
accuracy_metrics_evaluation(
    y_test,
    y_test_predict,
    'Test data Scores'
)
# Out:
# Test data Scores:
# MAE = 0.6324
# MSE = 0.7246
# RMSE = 0.8512
# R2 = 0.4565

# %%
# Check for Overlearning tendencies.
accuracy_metrics_evaluation(
    y_train,
    y_train_predict,
    'Train data Scores'
)
# Out:
# Train data Scores:
# MAE = 0.6232
# MSE = 0.6912
# RMSE = 0.8314
# R2 = 0.4806
